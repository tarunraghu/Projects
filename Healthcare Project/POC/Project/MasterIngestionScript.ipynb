# %%
from pyspark.sql import SparkSession

# Initialize Spark session
spark = SparkSession.builder.appName("MergeDataFrames").getOrCreate()

# Define the file paths
script1_path = 'USMD_Arlington.py'
#script2_path = 'WhiteRockMedicalCenter.py'
script3_path = 'Adventist_health_White_Memorial.py'
script4_path = 'UCLA_Resnick.py'
script5_path = 'BaylorScott_Irving.py'

# Create a dictionary to store the variables from the scripts
script1_globals = {}
#script2_globals = {}
script3_globals = {}
script4_globals = {}
script5_globals = {}

# Execute the scripts
with open(script1_path) as f:
    exec(f.read(), script1_globals)

#with open(script2_path) as f:
   #exec(f.read(), script2_globals)
    
with open(script3_path) as f:
    exec(f.read(), script3_globals)
    
with open(script4_path) as f:
    exec(f.read(), script4_globals)
    
with open(script5_path) as f:
    exec(f.read(), script5_globals)

# Access the DataFrames from the scripts
df1 = script1_globals['df_final']
#df2 = script2_globals['df_final']
df3 = script3_globals['df_final']
df4 = script4_globals['df_final']
df5 = script5_globals['df_final']

# Merge the DataFrames, borrowing the header from the first file and ignoring headers from other files
merged_df = df1.unionByName(df3).unionByName(df4).unionByName(df5)

# Show the merged DataFrame
merged_df.show(5)
# Out:
# +--------------------+------+-----------------+--------------------+----------------+-------------------+-------------------+
# |         description|code|1|       payer_name|           plan_name|estimated_amount|standard_charge|max|standard_charge|min|
# +--------------------+------+-----------------+--------------------+----------------+-------------------+-------------------+
# |HEART TRANSPLANT ...|   001|            Aetna|               Aetna|       553176.28|          835367.16|          553176.28|
# |HEART TRANSPLANT ...|   001|United Healthcare|United Healthcare...|        635848.5|          835367.16|          553176.28|
# |HEART TRANSPLANT ...|   001|United Healthcare|United Healthcare...|       835367.16|          835367.16|          553176.28|
# |HEART TRANSPLANT ...|   001|United Healthcare|United Healthcare...|        635848.5|          835367.16|          553176.28|
# |HEART TRANSPLANT ...|   002|            Aetna|               Aetna|       333274.32|          503286.98|          333274.32|
# |HEART TRANSPLANT ...|   002|United Healthcare|United Healthcare...|       383082.18|          503286.98|          333274.32|
# |HEART TRANSPLANT ...|   002|United Healthcare|United Healthcare...|       503286.98|          503286.98|          333274.32|
# |HEART TRANSPLANT ...|   002|United Healthcare|United Healthcare...|       383082.18|          503286.98|          333274.32|
# |ECMO OR TRACHEOST...|   003|            Aetna|               Aetna|       384837.16|          581153.49|          384837.16|
# |ECMO OR TRACHEOST...|   003|United Healthcare|United Healthcare...|       442351.09|          581153.49|          384837.16|
# |ECMO OR TRACHEOST...|   003|United Healthcare|United Healthcare...|       581153.49|          581153.49|          384837.16|
# |ECMO OR TRACHEOST...|   003|United Healthcare|United Healthcare...|       442351.09|          581153.49|          384837.16|
# |TRACHEOSTOMY WITH...|   004|            Aetna|               Aetna|       238466.42|          360114.89|          238466.42|
# |TRACHEOSTOMY WITH...|   004|United Healthcare|United Healthcare...|       274105.23|          360114.89|          238466.42|
# |TRACHEOSTOMY WITH...|   004|United Healthcare|United Healthcare...|       360114.89|          360114.89|          238466.42|
# |TRACHEOSTOMY WITH...|   004|United Healthcare|United Healthcare...|       274105.23|          360114.89|          238466.42|
# |LIVER TRANSPLANT ...|   005|            Aetna|               Aetna|       227394.95|          343395.55|          227394.95|
------+--------------------+--------------------+----------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# +---------------+----------+--------------------+------------------+---------------------+-------------------+-------------------+
# |    Description|    code|1|          payer_name|         plan_name|standard_charge|gross|standard_charge|max|standard_charge|min|
# +---------------+----------+--------------------+------------------+---------------------+-------------------+-------------------+
# |HB SINGLE PSYCH|1100011400|               Aetna|      All Products|               5930.0|             4804.0|             3040.0|
# |HB SINGLE PSYCH|1100011400|Anthem Vivity, An...|               HMO|               5930.0|             3844.0|              895.0|
# |HB SINGLE PSYCH|1100011400|Anthem Vivity, An...|      All Products|               5930.0|             3844.0|              895.0|
# |HB SINGLE PSYCH|1100011400|Anthem Vivity, An...|      All Products|               5930.0|             3844.0|              895.0|
# |HB SINGLE PSYCH|1100011400|Anthem Vivity, An...|               HMO|               5930.0|             3844.0|              895.0|
# |HB SINGLE PSYCH|1100011400|         Blue Shield|Medicare Advantage|               5930.0|               NULL|               NULL|
# |HB SINGLE PSYCH|1100011400|         Blue Shield|      All Products|               5930.0|             3844.0|              895.0|
# |HB SINGLE PSYCH|1100011400|         Blue Shield|               EPN|               5930.0|             3844.0|              895.0|
# |HB SINGLE PSYCH|1100011400|             Centivo|      All Products|               5930.0|             4804.0|             3040.0|
# |HB SINGLE PSYCH|1100011400|Department of Men...|          Medicaid|               5930.0|             3844.0|              895.0|
# |HB SINGLE PSYCH|1100011400|Department of Men...|          Medicaid|               5930.0|             3844.0|              895.0|
# |HB SINGLE PSYCH|1100011400|           Evernorth|               HMO|               5930.0|             3844.0|              895.0|
# |HB SINGLE PSYCH|1100011400|           Evernorth|               PPO|               5930.0|             3844.0|              895.0|
# |HB SINGLE PSYCH|1100011400|           Evernorth|               PPO|               5930.0|             3844.0|              895.0|
# |HB SINGLE PSYCH|1100011400|           Evernorth|               HMO|               5930.0|             3844.0|              895.0|
# |HB SINGLE PSYCH|1100011400|              Kaiser|      All Products|               5930.0|             3844.0|              895.0|
# |HB SINGLE PSYCH|1100011400|Magellan Human Af...|               PPO|               5930.0|             3844.0|              895.0|
# |HB SINGLE PSYCH|1100011400|Managed Health Ne...|      All Products|               5930.0|             3844.0|              895.0|
# |HB SINGLE PSYCH|1100011400|           Multiplan|               PPO|               5930.0|             4447.5|            1755.28|
# |HB SINGLE PSYCH|1100011400|          OBH USBHPC|      All Products|               5930.0|             3844.0|              895.0|
# +---------------+----------+--------------------+------------------+---------------------+-------------------+-------------------+
# only showing top 20 rows
#
# +-------------------+------------+--------------------+------------------+----------------------+--------------------+--------------------+
# |billing_description|billing_code|  insurance_provider|    insurance_plan|gross_standard_charges|max_standard_charges|min_standard_charges|
# +-------------------+------------+--------------------+------------------+----------------------+--------------------+--------------------+
# |    HB SINGLE PSYCH|  1100011400|               Aetna|      All Products|                5930.0|              4804.0|              3040.0|
# |    HB SINGLE PSYCH|  1100011400|Anthem Vivity, An...|               HMO|                5930.0|              3844.0|               895.0|
# |    HB SINGLE PSYCH|  1100011400|Anthem Vivity, An...|      All Products|                5930.0|              3844.0|               895.0|
# |    HB SINGLE PSYCH|  1100011400|Anthem Vivity, An...|      All Products|                5930.0|              3844.0|               895.0|
# |    HB SINGLE PSYCH|  1100011400|Anthem Vivity, An...|               HMO|                5930.0|              3844.0|               895.0|
# |    HB SINGLE PSYCH|  1100011400|         Blue Shield|Medicare Advantage|                5930.0|                NULL|                NULL|
# |    HB SINGLE PSYCH|  1100011400|         Blue Shield|      All Products|                5930.0|              3844.0|               895.0|
# |    HB SINGLE PSYCH|  1100011400|         Blue Shield|               EPN|                5930.0|              3844.0|               895.0|
# |    HB SINGLE PSYCH|  1100011400|             Centivo|      All Products|                5930.0|              4804.0|              3040.0|
# |    HB SINGLE PSYCH|  1100011400|Department of Men...|          Medicaid|                5930.0|              3844.0|               895.0|
# |    HB SINGLE PSYCH|  1100011400|Department of Men...|          Medicaid|                5930.0|              3844.0|               895.0|
# |    HB SINGLE PSYCH|  1100011400|           Evernorth|               HMO|                5930.0|              3844.0|               895.0|
# |    HB SINGLE PSYCH|  1100011400|           Evernorth|               PPO|                5930.0|              3844.0|               895.0|
# |    HB SINGLE PSYCH|  1100011400|           Evernorth|               PPO|                5930.0|              3844.0|               895.0|
# |    HB SINGLE PSYCH|  1100011400|           Evernorth|               HMO|                5930.0|              3844.0|               895.0|
# |    HB SINGLE PSYCH|  1100011400|              Kaiser|      All Products|                5930.0|              3844.0|               895.0|
# |    HB SINGLE PSYCH|  1100011400|Magellan Human Af...|               PPO|                5930.0|              3844.0|               895.0|
# |    HB SINGLE PSYCH|  1100011400|Managed Health Ne...|      All Products|                5930.0|              3844.0|               895.0|
# |    HB SINGLE PSYCH|  1100011400|           Multiplan|               PPO|                5930.0|              4447.5|             1755.28|
# |    HB SINGLE PSYCH|  1100011400|          OBH USBHPC|      All Products|                5930.0|              3844.0|               895.0|
# +-------------------+------------+--------------------+------------------+----------------------+--------------------+--------------------+
# only showing top 20 rows
#
# +-------------------+------------+--------------------+------------------+----------------------+--------------------+--------------------+-------------+
# |billing_description|billing_code|  insurance_provider|    insurance_plan|gross_standard_charges|max_standard_charges|min_standard_charges|hospital_name|
# +-------------------+------------+--------------------+------------------+----------------------+--------------------+--------------------+-------------+
# |    HB SINGLE PSYCH|  1100011400|               Aetna|      All Products|                5930.0|              4804.0|              3040.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|Anthem Vivity, An...|               HMO|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|Anthem Vivity, An...|      All Products|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|Anthem Vivity, An...|      All Products|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|Anthem Vivity, An...|               HMO|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|         Blue Shield|Medicare Advantage|                5930.0|                NULL|                NULL| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|         Blue Shield|      All Products|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|         Blue Shield|               EPN|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|             Centivo|      All Products|                5930.0|              4804.0|              3040.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|Department of Men...|          Medicaid|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|Department of Men...|          Medicaid|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|           Evernorth|               HMO|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|           Evernorth|               PPO|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|           Evernorth|               PPO|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|           Evernorth|               HMO|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|              Kaiser|      All Products|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|Magellan Human Af...|               PPO|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|Managed Health Ne...|      All Products|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|           Multiplan|               PPO|                5930.0|              4447.5|             1755.28| UCLA_Resnick|
# |    HB SINGLE PSYCH|  1100011400|          OBH USBHPC|      All Products|                5930.0|              3844.0|               895.0| UCLA_Resnick|
# +-------------------+------------+--------------------+------------------+----------------------+--------------------+--------------------+-------------+
# only showing top 20 rows
#
# +--------------------+--------+----------+----------+---------------------+-------------------+-------------------+
# |         description|  code|1|payer_name| plan_name|standard_charge|gross|standard_charge|max|standard_charge|min|
# +--------------------+--------+----------+----------+---------------------+-------------------+-------------------+
# |polidocanoL 1 % (...|63600031|     Aetna|Commercial|                120.0|               90.0|               40.8|
# |EPINEPHrine 0.1 m...|63600001|     Aetna|Commercial|                35.44|              26.58|               12.4|
# |EPINEPHrine 0.1 m...|63600001|     Aetna|Commercial|                 63.1|              47.32|              22.08|
# |EPINEPHrine 0.1 m...|63600001|     Aetna|Commercial|                50.02|              37.52|              17.51|
# |ibutilide fumarat...|63600031|     Aetna|Commercial|              1342.35|            1006.76|             180.73|
# |ibutilide fumarat...|63600031|     Aetna|Commercial|              1646.55|            1234.91|             180.73|
# |methylergonovine ...|63600001|     Aetna|Commercial|               179.52|             134.64|              61.04|
# |methylergonovine ...|63600001|     Aetna|Commercial|               179.52|             134.64|              61.04|
# |methylergonovine ...|63600001|     Aetna|Commercial|               118.56|              88.92|              40.31|
# |methylergonovine ...|63600001|     Aetna|Commercial|               118.56|              88.92|              40.31|
# |ROPivacaine (PF) ...|63600001|     Aetna|Commercial|               935.55|             701.66|             318.09|
# |ROPivacaine (PF) ...|63600001|     Aetna|Commercial|                454.5|             340.88|             154.53|
# |HYDROmorphone 0.2...|63600001|     Aetna|Commercial|                 69.0|              51.75|              23.46|
# |perflutren protei...|25500001|     Aetna|Commercial|                631.8|             505.44|             221.13|
# |cosyntropin 0.25 ...|63601051|     Aetna|Commercial|               479.61|             359.71|             163.07|
# |cosyntropin 0.25 ...|63601051|     Aetna|Commercial|                360.9|             270.68|             122.71|
# |palonosetron 0.25...|63600001|     Aetna|Commercial|                900.0|              675.0|              306.0|
# |palonosetron 0.25...|63600001|     Aetna|Commercial|                150.0|              112.5|               51.0|
# |palonosetron 0.25...|63600001|     Aetna|Commercial|                240.0|              180.0|               81.6|
# |buprenorphine HCL...|63600001|     Aetna|Commercial|                91.02|              68.26|              30.95|
# +--------------------+--------+----------+----------+---------------------+-------------------+-------------------+
# only showing top 20 rows
#
# +--------------------+------------+------------------+--------------+----------------------+--------------------+--------------------+
# | billing_description|billing_code|insurance_provider|insurance_plan|gross_standard_charges|max_standard_charges|min_standard_charges|
# +--------------------+------------+------------------+--------------+----------------------+--------------------+--------------------+
# |polidocanoL 1 % (...|    63600031|             Aetna|    Commercial|                 120.0|                90.0|                40.8|
# |EPINEPHrine 0.1 m...|    63600001|             Aetna|    Commercial|                 35.44|               26.58|                12.4|
# |EPINEPHrine 0.1 m...|    63600001|             Aetna|    Commercial|                  63.1|               47.32|               22.08|
# |EPINEPHrine 0.1 m...|    63600001|             Aetna|    Commercial|                 50.02|               37.52|               17.51|
# |ibutilide fumarat...|    63600031|             Aetna|    Commercial|               1342.35|             1006.76|              180.73|
# |ibutilide fumarat...|    63600031|             Aetna|    Commercial|               1646.55|             1234.91|              180.73|
# |methylergonovine ...|    63600001|             Aetna|    Commercial|                179.52|              134.64|               61.04|
# |methylergonovine ...|    63600001|             Aetna|    Commercial|                179.52|              134.64|               61.04|
# |methylergonovine ...|    63600001|             Aetna|    Commercial|                118.56|               88.92|               40.31|
# |methylergonovine ...|    63600001|             Aetna|    Commercial|                118.56|               88.92|               40.31|
# |ROPivacaine (PF) ...|    63600001|             Aetna|    Commercial|                935.55|              701.66|              318.09|
# |ROPivacaine (PF) ...|    63600001|             Aetna|    Commercial|                 454.5|              340.88|              154.53|
# |HYDROmorphone 0.2...|    63600001|             Aetna|    Commercial|                  69.0|               51.75|               23.46|
# |perflutren protei...|    25500001|             Aetna|    Commercial|                 631.8|              505.44|              221.13|
# |cosyntropin 0.25 ...|    63601051|             Aetna|    Commercial|                479.61|              359.71|              163.07|
# |cosyntropin 0.25 ...|    63601051|             Aetna|    Commercial|                 360.9|              270.68|              122.71|
# |palonosetron 0.25...|    63600001|             Aetna|    Commercial|                 900.0|               675.0|               306.0|
# |palonosetron 0.25...|    63600001|             Aetna|    Commercial|                 150.0|               112.5|                51.0|
# |palonosetron 0.25...|    63600001|             Aetna|    Commercial|                 240.0|               180.0|                81.6|
# |buprenorphine HCL...|    63600001|             Aetna|    Commercial|                 91.02|               68.26|               30.95|
# +--------------------+------------+------------------+--------------+----------------------+--------------------+--------------------+
# only showing top 20 rows
#
# +--------------------+------------+------------------+--------------+----------------------+--------------------+--------------------+------------------+
# | billing_description|billing_code|insurance_provider|insurance_plan|gross_standard_charges|max_standard_charges|min_standard_charges|     hospital_name|
# +--------------------+------------+------------------+--------------+----------------------+--------------------+--------------------+------------------+
# |polidocanoL 1 % (...|    63600031|             Aetna|    Commercial|                 120.0|                90.0|                40.8|BaylorScott_Irving|
# |EPINEPHrine 0.1 m...|    63600001|             Aetna|    Commercial|                 35.44|               26.58|                12.4|BaylorScott_Irving|
# |EPINEPHrine 0.1 m...|    63600001|             Aetna|    Commercial|                  63.1|               47.32|               22.08|BaylorScott_Irving|
# |EPINEPHrine 0.1 m...|    63600001|             Aetna|    Commercial|                 50.02|               37.52|               17.51|BaylorScott_Irving|
# |ibutilide fumarat...|    63600031|             Aetna|    Commercial|               1342.35|             1006.76|              180.73|BaylorScott_Irving|
# |ibutilide fumarat...|    63600031|             Aetna|    Commercial|               1646.55|             1234.91|              180.73|BaylorScott_Irving|
# |methylergonovine ...|    63600001|             Aetna|    Commercial|                179.52|              134.64|               61.04|BaylorScott_Irving|
# |methylergonovine ...|    63600001|             Aetna|    Commercial|                179.52|              134.64|               61.04|BaylorScott_Irving|
# |methylergonovine ...|    63600001|             Aetna|    Commercial|                118.56|               88.92|               40.31|BaylorScott_Irving|
# |methylergonovine ...|    63600001|             Aetna|    Commercial|                118.56|               88.92|               40.31|BaylorScott_Irving|
# |ROPivacaine (PF) ...|    63600001|             Aetna|    Commercial|                935.55|              701.66|              318.09|BaylorScott_Irving|
# |ROPivacaine (PF) ...|    63600001|             Aetna|    Commercial|                 454.5|              340.88|              154.53|BaylorScott_Irving|
# |HYDROmorphone 0.2...|    63600001|             Aetna|    Commercial|                  69.0|               51.75|               23.46|BaylorScott_Irving|
# |perflutren protei...|    25500001|             Aetna|    Commercial|                 631.8|              505.44|              221.13|BaylorScott_Irving|
# |cosyntropin 0.25 ...|    63601051|             Aetna|    Commercial|                479.61|              359.71|              163.07|BaylorScott_Irving|
# |cosyntropin 0.25 ...|    63601051|             Aetna|    Commercial|                 360.9|              270.68|              122.71|BaylorScott_Irving|
# |palonosetron 0.25...|    63600001|             Aetna|    Commercial|                 900.0|               675.0|               306.0|BaylorScott_Irving|
# |palonosetron 0.25...|    63600001|             Aetna|    Commercial|                 150.0|               112.5|                51.0|BaylorScott_Irving|
# |palonosetron 0.25...|    63600001|             Aetna|    Commercial|                 240.0|               180.0|                81.6|BaylorScott_Irving|
# |buprenorphine HCL...|    63600001|             Aetna|    Commercial|                 91.02|               68.26|               30.95|BaylorScott_Irving|
# +--------------------+------------+------------------+--------------+----------------------+--------------------+--------------------+------------------+
# only showing top 20 rows
#
# +--------------------+------------+------------------+--------------------+----------------------+--------------------+--------------------+--------------+
# | billing_description|billing_code|insurance_provider|      insurance_plan|gross_standard_charges|max_standard_charges|min_standard_charges| hospital_name|
# +--------------------+------------+------------------+--------------------+----------------------+--------------------+--------------------+--------------+
# |HEART TRANSPLANT ...|         001|             Aetna|               Aetna|             553176.28|           835367.16|           553176.28|USMD_Arlington|
# |HEART TRANSPLANT ...|         001| United Healthcare|United Healthcare...|              635848.5|           835367.16|           553176.28|USMD_Arlington|
# |HEART TRANSPLANT ...|         001| United Healthcare|United Healthcare...|             835367.16|           835367.16|           553176.28|USMD_Arlington|
# |HEART TRANSPLANT ...|         001| United Healthcare|United Healthcare...|              635848.5|           835367.16|           553176.28|USMD_Arlington|
# |HEART TRANSPLANT ...|         002|             Aetna|               Aetna|             333274.32|           503286.98|           333274.32|USMD_Arlington|
# +--------------------+------------+------------------+--------------------+----------------------+--------------------+--------------------+--------------+
# only showing top 5 rows

# %%
merged_df.show(5)
# Out:
# +--------------------+------------+------------------+--------------------+----------------------+--------------------+--------------------+--------------+
# | billing_description|billing_code|insurance_provider|      insurance_plan|gross_standard_charges|max_standard_charges|min_standard_charges| hospital_name|
# +--------------------+------------+------------------+--------------------+----------------------+--------------------+--------------------+--------------+
# |HEART TRANSPLANT ...|         001|             Aetna|               Aetna|             553176.28|           835367.16|           553176.28|USMD_Arlington|
# |HEART TRANSPLANT ...|         001| United Healthcare|United Healthcare...|              635848.5|           835367.16|           553176.28|USMD_Arlington|
# |HEART TRANSPLANT ...|         001| United Healthcare|United Healthcare...|             835367.16|           835367.16|           553176.28|USMD_Arlington|
# |HEART TRANSPLANT ...|         001| United Healthcare|United Healthcare...|              635848.5|           835367.16|           553176.28|USMD_Arlington|
# |HEART TRANSPLANT ...|         002|             Aetna|               Aetna|             333274.32|           503286.98|           333274.32|USMD_Arlington|
# +--------------------+------------+------------------+--------------------+----------------------+--------------------+--------------------+--------------+
# only showing top 5 rows

# %%
# Identify unique hospitals in the merged DataFrame
unique_hospitals = merged_df.select("hospital_name").distinct()
unique_hospitals.show(10)
# Out:
# +--------------------+
# |       hospital_name|
# +--------------------+
# |      USMD_Arlington|
# |Adventist_health_...|
# |        UCLA_Resnick|
# |  BaylorScott_Irving|
# +--------------------+

# %%
from pyspark.sql import SparkSession

# Initialize Spark session
spark = SparkSession.builder.appName("MergeDataFrames").getOrCreate()

# Assuming merged_df is already defined and available
# Register the DataFrame as a SQL temporary view
merged_df.createOrReplaceTempView("merged_table")

# SQL query to check for null values in each column grouped by hospital name
null_check_query_grouped = """
SELECT 
    hospital_name,
    SUM(CASE WHEN billing_description IS NULL THEN 1 ELSE 0 END) AS billing_description_nulls,
    SUM(CASE WHEN billing_code IS NULL THEN 1 ELSE 0 END) AS billing_code_nulls,
    SUM(CASE WHEN insurance_provider IS NULL THEN 1 ELSE 0 END) AS insurance_provider_nulls,
    SUM(CASE WHEN insurance_plan IS NULL THEN 1 ELSE 0 END) AS insurance_plan_nulls,
    SUM(CASE WHEN gross_standard_charges IS NULL THEN 1 ELSE 0 END) AS gross_standard_charges_nulls,
    SUM(CASE WHEN max_standard_charges IS NULL THEN 1 ELSE 0 END) AS max_standard_charges_nulls,
    SUM(CASE WHEN min_standard_charges IS NULL THEN 1 ELSE 0 END) AS min_standard_charges_nulls
FROM merged_table
GROUP BY hospital_name
"""

# Execute the query
null_counts_grouped = spark.sql(null_check_query_grouped)

# Show the result
null_counts_grouped.show()
# Out:
# +--------------------+-------------------------+------------------+------------------------+--------------------+----------------------------+--------------------------+--------------------------+
# |       hospital_name|billing_description_nulls|billing_code_nulls|insurance_provider_nulls|insurance_plan_nulls|gross_standard_charges_nulls|max_standard_charges_nulls|min_standard_charges_nulls|
# +--------------------+-------------------------+------------------+------------------------+--------------------+----------------------------+--------------------------+--------------------------+
# |      USMD_Arlington|                        0|                 6|                       0|                   0|                         231|                         6|                         6|
# |Adventist_health_...|                        0|                 0|                       0|                   0|                           0|                         0|                         0|
# |        UCLA_Resnick|                        0|                 0|                       0|                   0|                        6307|                         7|                         7|
# |  BaylorScott_Irving|                        0|                 0|                       0|                   0|                       12483|                         0|                         0|
# +--------------------+-------------------------+------------------+------------------------+--------------------+----------------------------+--------------------------+--------------------------+

# %%
# Assuming 'spark_df' is your Spark DataFrame
pandas_df = merged_df.toPandas()

# Now 'pandas_df' is a Pandas DataFrame
print(pandas_df.head())
# Out:
#                                  billing_description billing_code  \
# 0  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...          001
# 1  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...          001
# 2  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...          001
# 3  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...          001
# 4  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...          002
#
#   insurance_provider            insurance_plan  gross_standard_charges  \
# 0              Aetna                     Aetna               553176.28
# 1  United Healthcare     United Healthcare HMO               635848.50
# 2  United Healthcare  United Healthcare Option               835367.16
# 3  United Healthcare     United Healthcare PPO               635848.50
# 4              Aetna                     Aetna               333274.32
#
#    max_standard_charges  min_standard_charges   hospital_name
# 0             835367.16             553176.28  USMD_Arlington
# 1             835367.16             553176.28  USMD_Arlington
# 2             835367.16             553176.28  USMD_Arlington
# 3             835367.16             553176.28  USMD_Arlington
# 4             503286.98             333274.32  USMD_Arlington

# %%
import pandas as pd

# Assuming 'pandas_df' is your Pandas DataFrame
# Export the DataFrame to a CSV file with a pipe delimiter
pandas_df.to_csv("C:\\Users\\tarun\\Documents\\Semester 4\\Analytics Practicum\\POC\\Project\\merged_data.csv", sep='\t', index=False)

print("Pandas DataFrame has been exported to 'merged_data.csv' with a pipe delimiter.")
# Out:
# Pandas DataFrame has been exported to 'merged_data.csv' with a pipe delimiter.

# %%
# future scope : location, hospital name, branch_name, zipcode, latitude, longitude, city , state, phone, website, google maps link
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
